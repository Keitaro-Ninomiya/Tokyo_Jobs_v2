# %%
import json
import os
import pandas as pd
import numpy as np
import cv2

Year='1941'
Showa='16'

# %%
file_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Processed_Data\\'+Year+'\\DataFrame_Office.json'
with open(file_path, encoding="utf-8") as f:
    dta = json.loads(f.read())
df = pd.read_csv(r'C:/Users/Keitaro Ninomiya/Box/Research Notes (keitaro2@illinois.edu)/Tokyo_Jobs/Processed_Data/Index/S'+Showa+'.csv')
df=df.drop(df.columns[0], axis=1)

# %%
for n in range(0,len(df)):
    Row  = df.iloc[n]
    Dept=Row['Dept']
    Office=Row['Office']
    
    try:
        Info=dta[str(Year)][Dept][Office]
    except:
        continue
    PageList=Info['Page_Range']
    print(Info)
    StrPage=PageList[0]
    StrPart=Info['StrPart']
    StrCord=Info['StrLocation']

    EndPage=PageList[-1]
    EndPart=Info['EndPart']
    EndCord=Info['EndLocation']

    if (StrPage=="N"):
        continue
    if (EndPage=="A"):
        continue
    if (StrCord=="NA"):
        continue
    if (EndCord=="NA"):
        continue

    path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\'+str(Year)+'\\'
    save_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Office_Level\\'+str(Year)+'\\'+Dept+'\\'+Office+'\\'
    try:
        os.chdir(save_path)
    except:
        continue

    Count=1
    try:        
        if StrPage!=EndPage:
            print('Multiple Pages')
            for Page in PageList:
                if (Page==StrPage)&(StrPart=='Top'):
                    print("Starting at"+str(StrPage)+str(StrPart)+"|Count is"+str(Count))
                    img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\Top.jpg")
                    img=img[0:HH,0:StrCord]
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                    Count=Count+1

                    img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\"+'Btm'+".jpg")
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                    Count=Count+1

                if (Page==StrPage)&(StrPart=='Btm'):
                    print("Starting at"+str(StrPage)+str(StrPart)+"|Count is"+str(Count))
                    img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\Btm.jpg")
                    HH, WW = img.shape[:2]
                    img=img[0:HH,0:StrCord]
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                    Count=Count+1

                if (Page==EndPage)&(EndPart=='Top'):
                    print("Ending at"+str(EndPage)+"|Count is"+str(Count))
                    img=cv2.imread(path+"Page"+"{:03d}".format(EndPage)+"\\Top.jpg")
                    HH, WW = img.shape[:2]
                    img=img[0:HH,EndCord:WW]
                    cv2.imwrite('Image'+str(Count)+'.png', img)

                if (Page==EndPage)&(EndPart=='Btm'):
                    print("Ending at"+str(EndPage)+"|Count is"+str(Count))
                    img=cv2.imread(path+"Page"+"{:03d}".format(EndPage)+"\\Top.jpg")
                    HH, WW = img.shape[:2]
                    img=img[0:HH,0:WW]
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                    Count=Count+1

                    img=cv2.imread(path+"Page"+"{:03d}".format(EndPage)+"\\Btm.jpg")
                    HH, WW = img.shape[:2]
                    img=img[0:HH,EndCord:WW]
                    cv2.imwrite('Image'+str(Count)+'.png', img)

                else:
                    img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\Top.jpg")
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                    Count=Count+1

                    img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\Btm.jpg")
                    cv2.imwrite('Image'+str(Count)+'.png', img)

        if (StrPage==EndPage)&(StrPart!=EndPart):
            img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\Top.jpg")
            HH, WW = img.shape[:2]
            img=img[0:HH,0:StrCord]
            cv2.imwrite('Image'+str(Count)+'.png', img)
            Count=Count+1

            img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\Btm.jpg")
            HH, WW = img.shape[:2]
            img=img[0:HH,EndCord:WW]
            cv2.imwrite('Image'+str(Count)+'.png', img)

        if (StrPage==EndPage)&(StrPart==EndPart):
            img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\"+StrPart+".jpg")
            HH, WW = img.shape[:2]
            img=img[0:HH,EndCord:StrCord]
            cv2.imwrite('Image'+str(Count)+'.png', img)
    except:
        continue
# Out:
# {'Starting_Page': 3, 'StrLocation': 119, 'StrPart': 'Top', 'EndPage': 4, 'EndPart': 'Top', 'EndLocation': 356, 'Page_Range': [3, 4]}
# Multiple Pages
# Starting at3Top|Count is1
# Ending at4|Count is4
# {'StrPage': 4, 'StrLocation': 356, 'StrPart': 'Top', 'EndPage': 5, 'EndPart': 'Top', 'EndLocation': 375, 'Page_Range': [4, 5]}
# Multiple Pages
# Starting at4Top|Count is1
# Ending at5|Count is4
# {'StrPage': 5, 'StrLocation': 375, 'StrPart': 'Top', 'EndPage': 5, 'EndPart': 'Btm', 'EndLocation': 345, 'Page_Range': [5]}
# {'StrPage': 5, 'StrLocation': 345, 'StrPart': 'Btm', 'EndPage': 6, 'EndPart': 'Top', 'EndLocation': 154, 'Page_Range': [5, 6]}
# Multiple Pages
# Starting at5Btm|Count is1
# Ending at6|Count is3
# {'StrPage': 6, 'StrLocation': 154, 'StrPart': 'Top', 'EndPage': 6, 'EndLocation': 288, 'Page_Range': [6], 'EndPart': 'Btm'}
# {'StrPage': 6, 'StrLocation': 288, 'EndPage': 7, 'EndLocation': 319, 'Page_Range': [6, 7], 'StrPart': 'Btm', 'EndPart': 'Top'}
# Multiple Pages
# Starting at6Btm|Count is1
# Ending at7|Count is3
# {'StrPage': 7, 'StrLocation': 319, 'EndPage': 8, 'EndLocation': 371, 'Page_Range': [7, 8], 'EndPart': 'Btm', 'StrPart': 'Top'}
# Multiple Pages
# Starting at7Top|Count is1
# Ending at8|Count is4
# {'StrPage': 8, 'StrLocation': 371, 'StrPart': 'Btm', 'EndPage': 10, 'EndPart': 'Top', 'EndLocation': 241, 'Page_Range': [8, 9, 10]}
# Multiple Pages
# Starting at8Btm|Count is1
# Ending at10|Count is4
# {'StrPage': 10, 'StrLocation': 241, 'StrPart': 'Top', 'EndPage': 10, 'EndPart': 'Btm', 'EndLocation': 120, 'Page_Range': [10]}
# {'StrPage': 10, 'StrLocation': 120, 'StrPart': 'Btm', 'EndPage': 11, 'EndLocation': 82, 'Page_Range': [10, 11], 'EndPart': 'Top'}
# Multiple Pages
# Starting at10Btm|Count is1
# Ending at11|Count is3
# {'StrPage': 11, 'StrLocation': 82, 'EndPage': 12, 'EndPart': 'Top', 'EndLocation': 360, 'Page_Range': [11, 12], 'StrPart': 'Top'}
# Multiple Pages
# Starting at11Top|Count is1
# Ending at12|Count is4
# {'StrPage': 12, 'StrLocation': 360, 'StrPart': 'Top', 'EndPage': 13, 'EndPart': 'Top', 'EndLocation': 474, 'Page_Range': [12, 13]}
# Multiple Pages
# Starting at12Top|Count is1
# Ending at13|Count is4
# {'StrPage': 13, 'StrLocation': 474, 'StrPart': 'Top', 'EndPage': 13, 'EndPart': 'Btm', 'EndLocation': 400, 'Page_Range': [13]}
# {'StrPage': 13, 'StrLocation': 400, 'StrPart': 'Btm', 'EndPage': 15, 'EndLocation': 252, 'Page_Range': [13, 14, 15], 'EndPart': 'Btm'}
# Multiple Pages
# Starting at13Btm|Count is1
# Ending at15|Count is4
# {'StrPage': 15, 'StrLocation': 252, 'StrPart': 'Btm', 'EndPage': 16, 'EndPart': 'Top', 'EndLocation': 339, 'Page_Range': [15, 16]}
# Multiple Pages
# Starting at15Btm|Count is1
# Ending at16|Count is3
# {'StrPage': 16, 'StrLocation': 339, 'StrPart': 'Top', 'EndPage': 17, 'EndPart': 'Top', 'EndLocation': 281, 'Page_Range': [16, 17]}
# Multiple Pages
# Starting at16Top|Count is1
# Ending at17|Count is4
# {'StrPage': 17, 'StrLocation': 281, 'StrPart': 'Top', 'EndPage': 18, 'EndPart': 'Top', 'EndLocation': 358, 'Page_Range': [17, 18]}
# Multiple Pages
# Starting at17Top|Count is1
# Ending at18|Count is4
# {'StrPage': 18, 'StrLocation': 358, 'StrPart': 'Top', 'EndPage': 20, 'EndPart': 'Top', 'EndLocation': 436, 'Page_Range': [18, 19, 20]}
# Multiple Pages
# Starting at18Top|Count is1
# Ending at20|Count is5
# {'StrPage': 20, 'StrLocation': 436, 'StrPart': 'Top', 'EndPage': 20, 'EndLocation': 458, 'Page_Range': [20], 'EndPart': 'Btm'}
# {'StrPage': 20, 'StrLocation': 458, 'StrPart': 'Btm', 'EndPage': 21, 'EndLocation': 151, 'Page_Range': [20, 21], 'EndPart': 'Top'}
# Multiple Pages
# Starting at20Btm|Count is1
# Ending at21|Count is3
# {'StrPage': 21, 'StrLocation': 151, 'EndPage': 23, 'EndLocation': 477, 'Page_Range': [21, 22, 23], 'EndPart': 'Btm', 'StrPart': 'Top'}
# Multiple Pages
# Starting at21Top|Count is1
# Ending at23|Count is5
# {'StrPage': 23, 'StrLocation': 477, 'StrPart': 'Btm', 'EndPage': 24, 'EndPart': 'Top', 'EndLocation': 358, 'Page_Range': [23, 24]}
# Multiple Pages
# Starting at23Btm|Count is1
# Ending at24|Count is3
# {'StrPage': 24, 'StrLocation': 358, 'StrPart': 'Top', 'EndPage': 24, 'EndLocation': 448, 'Page_Range': [24], 'EndPart': 'Btm'}
# {'StrPage': 24, 'StrLocation': 448, 'StrPart': 'Btm', 'EndPage': 24, 'EndLocation': 358, 'Page_Range': [24], 'EndPart': 'Top'}
# {'StrPage': 24, 'StrLocation': 358, 'EndPage': 25, 'EndPart': 'Top', 'EndLocation': 222, 'Page_Range': [24, 25], 'StrPart': 'Top'}
# Multiple Pages
# Starting at24Top|Count is1
# Ending at25|Count is4
# {'StrPage': 25, 'StrLocation': 222, 'StrPart': 'Top', 'EndPage': 25, 'EndLocation': 172, 'Page_Range': [25], 'EndPart': 'Btm'}
# {'StrPage': 25, 'StrLocation': 172, 'StrPart': 'Btm', 'EndPage': 28, 'EndLocation': 500, 'Page_Range': [25, 26, 27, 28], 'EndPart': 'Btm'}
# Multiple Pages
# Starting at25Btm|Count is1
# Ending at28|Count is5
# {'StrPage': 28, 'StrLocation': 500, 'StrPart': 'Btm', 'EndPage': 28, 'EndLocation': 235, 'Page_Range': [28], 'EndPart': 'Btm'}
# {'StrPage': 28, 'StrLocation': 240, 'StrPart': 'Btm', 'EndPage': 29, 'EndPart': 'Top', 'EndLocation': 349, 'Page_Range': [28, 29]}
# Multiple Pages
# Starting at28Btm|Count is1
# Ending at29|Count is3
# {'StrPage': 29, 'StrLocation': 100, 'StrPart': 'Btm', 'EndPage': 30, 'EndPart': 'Btm', 'EndLocation': 153, 'Page_Range': [29, 30]}
# Multiple Pages
# Starting at29Btm|Count is1
# Ending at30|Count is3
# {'StrPage': 30, 'StrLocation': 155, 'StrPart': 'Btm', 'EndPage': 31, 'EndPart': 'Top', 'EndLocation': 258, 'Page_Range': [30, 31]}
# Multiple Pages
# Starting at30Btm|Count is1
# Ending at31|Count is3
# {'StrPage': 31, 'StrLocation': 260, 'StrPart': 'Top', 'EndPage': 32, 'EndPart': 'Top', 'EndLocation': 425, 'Page_Range': [31, 32]}
# Multiple Pages
# Starting at31Top|Count is1
# Ending at32|Count is4
# {'StrPage': 32, 'StrLocation': 425, 'StrPart': 'Top', 'EndPage': 32, 'EndPart': 'Btm', 'EndLocation': 225, 'Page_Range': [32]}
# {'StrPage': 32, 'StrLocation': 225, 'StrPart': 'Btm', 'EndPage': 33, 'EndLocation': 231, 'Page_Range': [32, 33], 'EndPart': 'Btm'}
# Multiple Pages
# Starting at32Btm|Count is1
# Ending at33|Count is3
# {'StrPage': 33, 'StrLocation': 231, 'StrPart': 'Btm', 'EndPage': 34, 'EndLocation': 223, 'Page_Range': [33, 34], 'EndPart': 'Top'}
# Multiple Pages
# Starting at33Btm|Count is1
# Ending at34|Count is3
# {'StrPage': 34, 'StrLocation': 223, 'EndPage': 34, 'EndLocation': 318, 'Page_Range': [34], 'EndPart': 'Btm', 'StrPart': 'Top'}
# {'StrPage': 34, 'StrLocation': 318, 'StrPart': 'Btm', 'EndPage': 'NA', 'EndLocation': 'NA', 'Page_Range': 'NA', 'EndPart': 'Top'}
# {'StrPage': 35, 'StrLocation': 380, 'EndPage': 36, 'EndPart': 'Top', 'EndLocation': 260, 'Page_Range': [35, 36], 'StrPart': 'Top'}
# Multiple Pages
# Starting at35Top|Count is1
# Ending at36|Count is4
# {'StrPage': 36, 'StrLocation': 260, 'StrPart': 'Top', 'EndPage': 37, 'EndLocation': 476, 'Page_Range': [36, 37], 'EndPart': 'Top'}
# Multiple Pages
# Starting at36Top|Count is1
# Ending at37|Count is4
# {'StrPage': 37, 'StrLocation': 476, 'EndPage': 38, 'EndPart': 'Top', 'EndLocation': 345, 'Page_Range': [37, 38], 'StrPart': 'Top'}
# Multiple Pages
# Starting at37Top|Count is1
# Ending at38|Count is4
# {'StrPage': 38, 'StrLocation': 345, 'StrPart': 'Top', 'EndPage': 39, 'EndPart': 'Btm', 'EndLocation': 325, 'Page_Range': [38, 39]}
# Multiple Pages
# Starting at38Top|Count is1
# Ending at39|Count is4
# {'StrPage': 39, 'StrLocation': 365, 'StrPart': 'Top', 'EndPage': 39, 'EndLocation': 326, 'Page_Range': [39], 'EndPart': 'Btm'}
# {'StrPage': 39, 'StrLocation': 326, 'StrPart': 'Btm', 'EndPage': 'NA', 'EndLocation': 'NA', 'Page_Range': 'NA', 'EndPart': 'Btm'}
# {'StrPage': 40, 'StrLocation': 320, 'StrPart': 'Btm', 'EndPage': 41, 'EndPart': 'Top', 'EndLocation': 230, 'Page_Range': [40, 41]}
# Multiple Pages
# Starting at40Btm|Count is1
# Ending at41|Count is3
# {'StrPage': 41, 'StrLocation': 230, 'StrPart': 'Top', 'EndPage': 42, 'EndPart': 'Btm', 'EndLocation': 148, 'Page_Range': [41, 42]}
# Multiple Pages
# Starting at41Top|Count is1
# Ending at42|Count is4
# {'StrPage': 42, 'StrLocation': 150, 'StrPart': 'Btm', 'EndPage': 46, 'EndPart': 'Top', 'EndLocation': 104, 'Page_Range': [42, 43, 44, 45, 46]}
# Multiple Pages
# Starting at42Btm|Count is1
# Ending at46|Count is6
# {'StrPage': 46, 'StrLocation': 104, 'StrPart': 'Top', 'EndPage': 49, 'EndPart': 'Btm', 'EndLocation': 270, 'Page_Range': [46, 47, 48, 49]}
# Multiple Pages
# Starting at46Top|Count is1
# Ending at49|Count is6
# {'StrPage': 49, 'StrLocation': 270, 'StrPart': 'Btm', 'EndPage': 54, 'EndPart': 'Top', 'EndLocation': 426, 'Page_Range': [49, 50, 51, 52, 53, 54]}
# Multiple Pages
# Starting at49Btm|Count is1
# Ending at54|Count is7
# {'StrPage': 54, 'StrLocation': 426, 'StrPart': 'Top', 'EndPage': 55, 'EndPart': 'Top', 'EndLocation': 183, 'Page_Range': [54, 55]}
# Multiple Pages
# Starting at54Top|Count is1
# Ending at55|Count is4
# {'StrPage': 55, 'StrLocation': 183, 'StrPart': 'Top', 'EndPage': 56, 'EndPart': 'Top', 'EndLocation': 377, 'Page_Range': [55, 56]}
# Multiple Pages
# Starting at55Top|Count is1
# Ending at56|Count is4
# {'StrPage': 56, 'StrLocation': 377, 'StrPart': 'Top', 'EndPage': 57, 'EndLocation': 471, 'Page_Range': [56, 57], 'EndPart': 'Btm'}
# Multiple Pages
# Starting at56Top|Count is1
# Ending at57|Count is4
# {'StrPage': 57, 'StrLocation': 470, 'StrPart': 'Btm', 'EndPage': 73, 'EndLocation': 207, 'Page_Range': [57, 58, 59, 60, 61, 62, 63, 64, 65, 66, 67, 68, 69, 70, 71, 72, 73], 'EndPart': 'Top'}
# Multiple Pages
# Starting at57Btm|Count is1
# Ending at73|Count is18
# {'StrPage': 76, 'StrLocation': 160, 'EndPage': 76, 'EndLocation': 151, 'Page_Range': [73, 74, 75, 76], 'StrPart': 'Top', 'EndPart': 'Top'}
# Multiple Pages
# Starting at73Top|Count is1
# Ending at76|Count is6
# {'StrPage': 76, 'StrLocation': 100, 'EndPage': 76, 'EndPart': 'Top', 'EndLocation': 151, 'Page_Range': [76], 'StrPart': 'Top'}
# {'StrPage': 76, 'StrLocation': 170, 'StrPart': 'Btm', 'EndPage': 79, 'EndPart': 'Top', 'EndLocation': 354, 'Page_Range': [76, 77, 78, 79]}
# Multiple Pages
# Starting at76Btm|Count is1
# Ending at79|Count is5
# {'StrPage': 79, 'StrLocation': 354, 'StrPart': 'Top', 'EndPage': 79, 'EndLocation': 398, 'Page_Range': [79], 'EndPart': 'Btm'}
# {'StrPage': 79, 'StrLocation': 398, 'StrPart': 'Btm', 'EndPage': 80, 'EndPart': 'Top', 'EndLocation': 472, 'Page_Range': [79, 80]}
# Multiple Pages
# Starting at79Btm|Count is1
# Ending at80|Count is3
# {'StrPage': 80, 'StrLocation': 472, 'StrPart': 'Top', 'EndPage': 80, 'EndLocation': 400, 'Page_Range': [80], 'EndPart': 'Btm'}
# {'StrPage': 80, 'StrLocation': 400, 'EndPage': 80, 'EndLocation': 471, 'Page_Range': [80], 'StrPart': 'Btm', 'EndPart': 'Top'}
# {'StrPage': 80, 'StrLocation': 145, 'EndPage': 81, 'EndLocation': 471, 'Page_Range': [80, 81], 'EndPart': 'Btm', 'StrPart': 'Btm'}
# Multiple Pages
# Starting at80Btm|Count is1
# Ending at81|Count is3
# {'StrPage': 81, 'StrLocation': 471, 'StrPart': 'Btm', 'EndPage': 82, 'EndPart': 'Top', 'EndLocation': 411, 'Page_Range': [81, 82]}
# Multiple Pages
# Starting at81Btm|Count is1
# Ending at82|Count is3
# {'StrPage': 82, 'StrLocation': 411, 'StrPart': 'Top', 'EndPage': 83, 'EndPart': 'Top', 'EndLocation': 166, 'Page_Range': [82, 83]}
# Multiple Pages
# Starting at82Top|Count is1
# Ending at83|Count is4
# {'StrPage': 83, 'StrLocation': 166, 'StrPart': 'Top', 'EndPage': 83, 'EndLocation': 329, 'Page_Range': [83], 'EndPart': 'Btm'}
# {'StrPage': 83, 'StrLocation': 329, 'StrPart': 'Btm', 'EndPage': 84, 'EndLocation': 156, 'Page_Range': [83, 84], 'EndPart': 'Top'}
# Multiple Pages
# Starting at83Btm|Count is1
# Ending at84|Count is3
# {'StrPage': 84, 'StrLocation': 90, 'StrPart': 'Top', 'EndPage': 85, 'EndPart': 'Top', 'EndLocation': 201, 'Page_Range': [84, 85]}
# Multiple Pages
# Starting at84Top|Count is1
# Ending at85|Count is4
# {'StrPage': 85, 'StrLocation': 540, 'StrPart': 'Top', 'EndPage': 85, 'EndPart': 'Top', 'EndLocation': 200, 'Page_Range': [85]}
# {'StrPage': 85, 'StrLocation': 200, 'StrPart': 'Top', 'EndPage': 86, 'EndPart': 'Top', 'EndLocation': 355, 'Page_Range': [85, 86]}
# Multiple Pages
# Starting at85Top|Count is1
# Ending at86|Count is4
# {'StrPage': 86, 'StrLocation': 355, 'StrPart': 'Top', 'EndPage': 86, 'EndLocation': 255, 'Page_Range': [86], 'EndPart': 'Btm'}
# {'StrPage': 86, 'StrLocation': 255, 'StrPart': 'Btm', 'EndPage': 87, 'EndLocation': 244, 'Page_Range': [86, 87], 'EndPart': 'Btm'}
# Multiple Pages
# Starting at86Btm|Count is1
# Ending at87|Count is3
# {'StrPage': 87, 'StrLocation': 500, 'EndPage': 87, 'EndLocation': 245, 'Page_Range': [87], 'EndPart': 'Btm', 'StrPart': 'Btm'}
# {'StrPage': 87, 'StrLocation': 245, 'StrPart': 'Btm', 'EndPage': 88, 'EndLocation': 250, 'Page_Range': [87, 88], 'EndPart': 'Btm'}
# Multiple Pages
# Starting at87Btm|Count is1
# Ending at88|Count is3
# {'StrPage': 88, 'StrLocation': 250, 'StrPart': 'Btm', 'EndPage': 'NA', 'EndLocation': 'NA', 'Page_Range': 'NA', 'EndPart': 'Top'}
# {'StrPage': 90, 'StrLocation': 40, 'EndPage': 91, 'EndLocation': 239, 'Page_Range': [90, 91], 'EndPart': 'Btm', 'StrPart': 'Top'}
# Multiple Pages
# Starting at90Top|Count is1
# Ending at91|Count is4
# {'StrPage': 91, 'StrLocation': 239, 'StrPart': 'Btm', 'EndPage': 'NA', 'EndPart': 'Top', 'EndLocation': 'NA', 'Page_Range': 'NA'}
# {'StrPage': 92, 'StrLocation': 100, 'StrPart': 'Top', 'EndPage': 93, 'EndLocation': 303, 'Page_Range': [92, 93], 'EndPart': 'Top'}
# Multiple Pages
# Starting at92Top|Count is1
# Ending at93|Count is4
# {'StrPage': 93, 'StrLocation': 303, 'EndPage': 94, 'EndPart': 'Top', 'EndLocation': 440, 'Page_Range': [93, 94], 'StrPart': 'Top'}
# Multiple Pages
# Starting at93Top|Count is1
# Ending at94|Count is4
# {'StrPage': 94, 'StrLocation': 440, 'StrPart': 'Top', 'EndPage': 94, 'EndPart': 'Top', 'EndLocation': 180, 'Page_Range': [94]}
# {'StrPage': 94, 'StrLocation': 180, 'StrPart': 'Top', 'EndPage': 101, 'EndPart': 'Top', 'EndLocation': 402, 'Page_Range': [94, 95, 96, 97, 98, 99, 100, 101]}
# Multiple Pages
# Starting at94Top|Count is1
# Ending at101|Count is10
# {'StrPage': 101, 'StrLocation': 402, 'StrPart': 'Top', 'EndPage': 101, 'EndLocation': 395, 'Page_Range': [101], 'EndPart': 'Btm'}
# {'StrPage': 101, 'StrLocation': 395, 'StrPart': 'Btm', 'EndPage': 102, 'EndLocation': 391, 'Page_Range': [101, 102], 'EndPart': 'Btm'}
# Multiple Pages
# Starting at101Btm|Count is1
# Ending at102|Count is3
# {'StrPage': 102, 'StrLocation': 330, 'EndPage': 102, 'EndLocation': 391, 'Page_Range': [102], 'EndPart': 'Btm', 'StrPart': 'Top'}
# {'StrPage': 102, 'StrLocation': 391, 'StrPart': 'Btm', 'EndPage': 103, 'EndLocation': 403, 'Page_Range': [102, 103], 'EndPart': 'Btm'}
# Multiple Pages
# Starting at102Btm|Count is1
# Ending at103|Count is3
# {'StrPage': 103, 'StrLocation': 403, 'StrPart': 'Btm', 'EndPage': 104, 'EndPart': 'Top', 'EndLocation': 286, 'Page_Range': [103, 104]}
# Multiple Pages
# Starting at103Btm|Count is1
# Ending at104|Count is3
# {'StrPage': 104, 'StrLocation': 290, 'StrPart': 'Top', 'EndPage': 104, 'EndLocation': 286, 'Page_Range': [104], 'EndPart': 'Top'}
# {'StrPage': 104, 'StrLocation': 180, 'EndPage': 105, 'EndPart': 'Top', 'EndLocation': 531, 'Page_Range': [104, 105], 'StrPart': 'Top'}
# Multiple Pages
# Starting at104Top|Count is1
# Ending at105|Count is4
# {'StrPage': 124, 'StrLocation': 490, 'StrPart': 'Top', 'EndPage': 124, 'EndLocation': 428, 'Page_Range': [124], 'EndPart': 'Btm'}
# {'StrPage': 105, 'StrLocation': 171, 'StrPart': 'Btm', 'EndPage': 106, 'EndPart': 'Top', 'EndLocation': 190, 'Page_Range': [105, 106]}
# Multiple Pages
# Starting at105Btm|Count is1
# Ending at106|Count is3
# {'StrPage': 106, 'StrLocation': 190, 'StrPart': 'Top', 'EndPage': 116, 'EndPart': 'Btm', 'EndLocation': 240, 'Page_Range': [106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116]}
# Multiple Pages
# Starting at106Top|Count is1
# Ending at116|Count is13
# {'StrPage': 116, 'StrLocation': 240, 'StrPart': 'Btm', 'EndPage': 'NA', 'EndLocation': 'NA', 'Page_Range': 'NA', 'EndPart': 'Top'}
# {'StrPage': 118, 'StrLocation': 70, 'EndPage': 119, 'EndPart': 'Top', 'EndLocation': 403, 'Page_Range': [118, 119], 'StrPart': 'Top'}
# Multiple Pages
# Starting at118Top|Count is1
# Ending at119|Count is4
# {'StrPage': 119, 'StrLocation': 403, 'StrPart': 'Top', 'EndPage': 123, 'EndLocation': 178, 'Page_Range': [119, 120, 121, 122, 123], 'EndPart': 'Btm'}
# Multiple Pages
# Starting at119Top|Count is1
# Ending at123|Count is7
# {'StrPage': 123, 'StrLocation': 180, 'StrPart': 'Btm', 'EndPage': 121, 'EndPart': 'Top', 'EndLocation': 503, 'Page_Range': []}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Temp\ipykernel_576\3281659670.py in <module>
#      10     PageList=Info['Page_Range']
#      11     print(Info)
# ---> 12     StrPage=PageList[0]
#      13     StrPart=Info['StrPart']
#      14     StrCord=Info['StrLocation']
#
# IndexError: list index out of range

# %%
dta[Year]['総務局']['文書課']
# Out:
# {'StrPage': 4,
#  'StrLocation': 356,
#  'StrPart': 'Top',
#  'EndPage': 5,
#  'EndPart': 'Top',
#  'EndLocation': 375,
#  'Page_Range': [4, 5]}
