# %%
import json
import os
import pandas as pd
import numpy as np
import cv2

Year='1939'
Showa='14'

# %%
file_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Processed_Data\\'+Year+'\\DataFrame_Office.json'
with open(file_path, encoding="utf-8") as f:
    dta = json.loads(f.read())
df = pd.read_csv(r'C:/Users/Keitaro Ninomiya/Box/Research Notes (keitaro2@illinois.edu)/Tokyo_Jobs/Processed_Data/Index/S'+Showa+'.csv')
df=df.drop(df.columns[0], axis=1)

# %%
for n in range(0,len(df)):
    
    Row  = df.iloc[n]
    Dept=Row['Dept']
    Office=Row['Office']

    Info=dta[str(Year)][Dept][Office]
    try:
        PageList=Info['Page_Range']
    except:
        continue

    print(Info)
    try:        
        StrPage=PageList[0]
        StrCord=Info['Office_X1']
        EndPage=PageList[-1]
        EndCord=Info['Office_X2']
    except:
        continue
    
    if (StrPage=="N"):
        continue
    if (EndPage=="A"):
        continue
    if (StrCord=="NA"):
        continue
    if (EndCord=="NA"):
        continue

    path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\'+str(Year)+'\\'
    save_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Office_Level\\'+str(Year)+'\\'+Dept+'\\'+Office+'\\'
    try:
        os.chdir(save_path)
    except:
        continue

    Count=1
    try:        
        if StrPage!=EndPage:
            for Page in PageList:
                if Page==StrPage:
                    print("Starting at"+str(Page)+"|Count is"+str(Count))
                    img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
                    HH, WW = img.shape[:2]
                    img=img[0:HH,0:StrCord]
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                    Count=Count+1
                if Page==EndPage:
                    print("Ending at"+str(Page)+"|Count is"+str(Count))
                    img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
                    HH, WW = img.shape[:2]
                    img=img[0:HH,EndCord:WW]
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                if (Page!=StrPage) and (Page<EndPage):
                    print("Continuing at"+str(Page)+"|Count is"+str(Count))
                    img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\"+"Page"+"{:03d}".format(Page)+".jpg")
                    HH, WW = img.shape[:2]
                    img=img[0:HH,0:WW]
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                    Count=Count+1
        if StrPage==EndPage:
            img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\"+"Page"+"{:03d}".format(StrPage)+".jpg")
            HH, WW = img.shape[:2]
            img=img[0:HH,EndCord:StrCord]
            cv2.imwrite('Image'+str(Count)+'.png', img)
            
    except:
        continue
# Out:
# {'Starting_Page': 2, 'Office_X1': 20, 'Ending_Page': 5, 'Office_X2': 360, 'Page_Range': [2, 3, 4, 5]}
# Starting at2|Count is1
# Continuing at3|Count is2
# Continuing at4|Count is3
# Ending at5|Count is4
# {'Starting_Page': 5, 'Office_X1': 360, 'Ending_Page': 6, 'Office_X2': 283, 'Page_Range': [5, 6]}
# Starting at5|Count is1
# Ending at6|Count is2
# {'Starting_Page': 6, 'Office_X1': 283, 'Ending_Page': 7, 'Office_X2': 335, 'Page_Range': [6, 7]}
# Starting at6|Count is1
# Ending at7|Count is2
# {'Starting_Page': 7, 'Office_X1': 335, 'Ending_Page': 8, 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 8, 'Office_X1': None, 'Ending_Page': 9, 'Office_X2': 345, 'Page_Range': [8, 9]}
# Starting at8|Count is1
# Ending at9|Count is2
# {'Starting_Page': 9, 'Office_X1': 345, 'Ending_Page': 12, 'Office_X2': 340, 'Page_Range': [9, 10, 11, 12]}
# Starting at9|Count is1
# Continuing at10|Count is2
# Continuing at11|Count is3
# Ending at12|Count is4
# {'Starting_Page': 15, 'Office_X1': 496, 'Ending_Page': 16, 'Office_X2': 314, 'Page_Range': [15, 16]}
# Starting at15|Count is1
# Ending at16|Count is2
# {'Starting_Page': 16, 'Office_X1': 304, 'Ending_Page': 17, 'Office_X2': 145, 'Page_Range': [16, 17]}
# Starting at16|Count is1
# Ending at17|Count is2
# {'Starting_Page': 17, 'Office_X1': 145, 'Ending_Page': 20, 'Office_X2': 464, 'Page_Range': [17, 18, 19, 20]}
# Starting at17|Count is1
# Continuing at18|Count is2
# Continuing at19|Count is3
# Ending at20|Count is4
# {'Starting_Page': 21, 'Office_X1': 284, 'Ending_Page': 28, 'Office_X2': 197, 'Page_Range': [21, 22, 23, 24, 25, 26, 27, 28]}
# Starting at21|Count is1
# Continuing at22|Count is2
# Continuing at23|Count is3
# Continuing at24|Count is4
# Continuing at25|Count is5
# Continuing at26|Count is6
# Continuing at27|Count is7
# Ending at28|Count is8
# {'Starting_Page': 28, 'Office_X1': 197, 'Ending_Page': 89, 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 89, 'Office_X1': None, 'Ending_Page': 32, 'Office_X2': 464, 'Page_Range': []}
# {'Starting_Page': 32, 'Office_X1': 464, 'Ending_Page': 35, 'Office_X2': 397, 'Page_Range': [32, 33, 34, 35]}
# Starting at32|Count is1
# Continuing at33|Count is2
# Continuing at34|Count is3
# Ending at35|Count is4
# {'Starting_Page': 35, 'Office_X1': 397, 'Ending_Page': 40, 'Office_X2': 416, 'Page_Range': [35, 36, 37, 38, 39, 40]}
# Starting at35|Count is1
# Continuing at36|Count is2
# Continuing at37|Count is3
# Continuing at38|Count is4
# Continuing at39|Count is5
# Ending at40|Count is6
# {'Starting_Page': 40, 'Office_X1': 406, 'Ending_Page': 43, 'Office_X2': 465, 'Page_Range': [40, 41, 42, 43]}
# Starting at40|Count is1
# Continuing at41|Count is2
# Continuing at42|Count is3
# Ending at43|Count is4
# {'Starting_Page': 43, 'Office_X1': 455, 'Ending_Page': 44, 'Office_X2': 92, 'Page_Range': [43, 44]}
# Starting at43|Count is1
# Ending at44|Count is2
# {'Starting_Page': 44, 'Office_X1': 92, 'Ending_Page': 45, 'Office_X2': 94, 'Page_Range': [44, 45]}
# Starting at44|Count is1
# Ending at45|Count is2
# {'Starting_Page': 45, 'Office_X1': 94, 'Ending_Page': 47, 'Office_X2': 200, 'Page_Range': [45, 46, 47]}
# Starting at45|Count is1
# Continuing at46|Count is2
# Ending at47|Count is3
# {'Starting_Page': 47, 'Office_X1': 190, 'Ending_Page': 52, 'Office_X2': 172, 'Page_Range': [47, 48, 49, 50, 51, 52]}
# Starting at47|Count is1
# Continuing at48|Count is2
# Continuing at49|Count is3
# Continuing at50|Count is4
# Continuing at51|Count is5
# Ending at52|Count is6
# {'Starting_Page': 52, 'Office_X1': 172, 'Ending_Page': 53, 'Office_X2': 231, 'Page_Range': [52, 53]}
# Starting at52|Count is1
# Ending at53|Count is2
# {'Starting_Page': 53, 'Office_X1': 221, 'Ending_Page': 60, 'Office_X2': 342, 'Page_Range': [53, 54, 55, 56, 57, 58, 59, 60]}
# Starting at53|Count is1
# Continuing at54|Count is2
# Continuing at55|Count is3
# Continuing at56|Count is4
# Continuing at57|Count is5
# Continuing at58|Count is6
# Continuing at59|Count is7
# Ending at60|Count is8
# {'Starting_Page': 60, 'Office_X1': 332, 'Ending_Page': 62, 'Office_X2': 317, 'Page_Range': [60, 61, 62]}
# Starting at60|Count is1
# Continuing at61|Count is2
# Ending at62|Count is3
# {'Starting_Page': 63, 'Office_X1': 519, 'Ending_Page': 64, 'Office_X2': 482, 'Page_Range': [63, 64]}
# Starting at63|Count is1
# Ending at64|Count is2
# {'Starting_Page': 64, 'Office_X1': 482, 'Ending_Page': 64, 'Office_X2': 172, 'Page_Range': [64]}
# {'Starting_Page': 64, 'Office_X1': 172, 'Ending_Page': 65, 'Office_X2': 312, 'Page_Range': [64, 65]}
# Starting at64|Count is1
# Ending at65|Count is2
# {'Starting_Page': 65, 'Office_X1': 302, 'Ending_Page': 66, 'Office_X2': 290, 'Page_Range': [65, 66]}
# Starting at65|Count is1
# Ending at66|Count is2
# {'Starting_Page': 66, 'Office_X1': 290, 'Ending_Page': 67, 'Office_X2': 263, 'Page_Range': [66, 67]}
# Starting at66|Count is1
# Ending at67|Count is2
# {'Starting_Page': 67, 'Office_X1': None, 'Ending_Page': 70, 'Office_X2': 463, 'Page_Range': [67, 68, 69, 70]}
# Starting at67|Count is1
# Continuing at68|Count is2
# Continuing at69|Count is3
# Ending at70|Count is4
# {'Starting_Page': 70, 'Office_X1': 453, 'Ending_Page': 71, 'Office_X2': 362, 'Page_Range': [70, 71]}
# Starting at70|Count is1
# Ending at71|Count is2
# {'Starting_Page': 71, 'Office_X1': 352, 'Ending_Page': 74, 'Office_X2': 428, 'Page_Range': [71, 72, 73, 74]}
# Starting at71|Count is1
# Continuing at72|Count is2
# Continuing at73|Count is3
# Ending at74|Count is4
# {'Starting_Page': 75, 'Office_X1': 527, 'Ending_Page': 77, 'Office_X2': 558, 'Page_Range': [75, 76, 77]}
# Starting at75|Count is1
# Continuing at76|Count is2
# Ending at77|Count is3
# {'Starting_Page': 77, 'Office_X1': 548, 'Ending_Page': 78, 'Office_X2': 449, 'Page_Range': [77, 78]}
# Starting at77|Count is1
# Ending at78|Count is2
# {'Starting_Page': 78, 'Office_X1': 449, 'Ending_Page': 85, 'Office_X2': 229, 'Page_Range': [78, 79, 80, 81, 82, 83, 84, 85]}
# Starting at78|Count is1
# Continuing at79|Count is2
# Continuing at80|Count is3
# Continuing at81|Count is4
# Continuing at82|Count is5
# Continuing at83|Count is6
# Continuing at84|Count is7
# Ending at85|Count is8
# {'Starting_Page': 85, 'Office_X1': 229, 'Ending_Page': 92, 'Office_X2': 19, 'Page_Range': [85, 86, 87, 88, 89, 90, 91, 92]}
# Starting at85|Count is1
# Continuing at86|Count is2
# Continuing at87|Count is3
# Continuing at88|Count is4
# Continuing at89|Count is5
# Continuing at90|Count is6
# Continuing at91|Count is7
# Ending at92|Count is8
# {'Starting_Page': 92, 'Office_X1': 19, 'Ending_Page': 101, 'Office_X2': 455, 'Page_Range': [92, 93, 94, 95, 96, 97, 98, 99, 100, 101]}
# Starting at92|Count is1
# Continuing at93|Count is2
# Continuing at94|Count is3
# Continuing at95|Count is4
# Continuing at96|Count is5
# Continuing at97|Count is6
# Continuing at98|Count is7
# Continuing at99|Count is8
# Continuing at100|Count is9
# Ending at101|Count is10
# {'Starting_Page': 101, 'Office_X1': 455, 'Ending_Page': 114, 'Office_X2': 317, 'Page_Range': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114]}
# Starting at101|Count is1
# Continuing at102|Count is2
# Continuing at103|Count is3
# Continuing at104|Count is4
# Continuing at105|Count is5
# Continuing at106|Count is6
# Continuing at107|Count is7
# Continuing at108|Count is8
# Continuing at109|Count is9
# Continuing at110|Count is10
# Continuing at111|Count is11
# Continuing at112|Count is12
# Continuing at113|Count is13
# Ending at114|Count is14
# {'Starting_Page': 114, 'Office_X1': 317, 'Ending_Page': 118, 'Office_X2': 212, 'Page_Range': [114, 115, 116, 117, 118]}
# Starting at114|Count is1
# Continuing at115|Count is2
# Continuing at116|Count is3
# Continuing at117|Count is4
# Ending at118|Count is5
# {'Starting_Page': 118, 'Office_X1': 212, 'Ending_Page': 121, 'Office_X2': 262, 'Page_Range': [118, 119, 120, 121]}
# Starting at118|Count is1
# Continuing at119|Count is2
# Continuing at120|Count is3
# Ending at121|Count is4
# {'Starting_Page': 121, 'Office_X1': 252, 'Ending_Page': 125, 'Office_X2': 167, 'Page_Range': [121, 122, 123, 124, 125]}
# Starting at121|Count is1
# Continuing at122|Count is2
# Continuing at123|Count is3
# Continuing at124|Count is4
# Ending at125|Count is5
# {'Starting_Page': 125, 'Office_X1': 157, 'Ending_Page': 132, 'Office_X2': 192, 'Page_Range': [125, 126, 127, 128, 129, 130, 131, 132]}
# Starting at125|Count is1
# Continuing at126|Count is2
# Continuing at127|Count is3
# Continuing at128|Count is4
# Continuing at129|Count is5
# Continuing at130|Count is6
# Continuing at131|Count is7
# Ending at132|Count is8
# {'Starting_Page': 132, 'Office_X1': 192, 'Ending_Page': 133, 'Office_X2': 198, 'Page_Range': [132, 133]}
# Starting at132|Count is1
# Ending at133|Count is2
# {'Starting_Page': 133, 'Office_X1': 198, 'Ending_Page': 135, 'Office_X2': 499, 'Page_Range': [133, 134, 135]}
# Starting at133|Count is1
# Continuing at134|Count is2
# Ending at135|Count is3
# {'Starting_Page': 135, 'Office_X1': 499, 'Ending_Page': 137, 'Office_X2': 154, 'Page_Range': [135, 136, 137]}
# Starting at135|Count is1
# Continuing at136|Count is2
# Ending at137|Count is3
# {'Starting_Page': 137, 'Office_X1': 154, 'Ending_Page': 138, 'Office_X2': 259, 'Page_Range': [137, 138]}
# Starting at137|Count is1
# Ending at138|Count is2
# {'Starting_Page': 138, 'Office_X1': None, 'Ending_Page': 175, 'Office_X2': 114, 'Page_Range': [138, 139, 140, 141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160, 161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173, 174, 175]}
# Starting at138|Count is1
# Continuing at139|Count is2
# Continuing at140|Count is3
# Continuing at141|Count is4
# Continuing at142|Count is5
# Continuing at143|Count is6
# Continuing at144|Count is7
# Continuing at145|Count is8
# Continuing at146|Count is9
# Continuing at147|Count is10
# Continuing at148|Count is11
# Continuing at149|Count is12
# Continuing at150|Count is13
# Continuing at151|Count is14
# Continuing at152|Count is15
# Continuing at153|Count is16
# Continuing at154|Count is17
# Continuing at155|Count is18
# Continuing at156|Count is19
# Continuing at157|Count is20
# Continuing at158|Count is21
# Continuing at159|Count is22
# Continuing at160|Count is23
# Continuing at161|Count is24
# Continuing at162|Count is25
# Continuing at163|Count is26
# Continuing at164|Count is27
# Continuing at165|Count is28
# Continuing at166|Count is29
# Continuing at167|Count is30
# Continuing at168|Count is31
# Continuing at169|Count is32
# Continuing at170|Count is33
# Continuing at171|Count is34
# Continuing at172|Count is35
# Continuing at173|Count is36
# Continuing at174|Count is37
# Ending at175|Count is38
# {'Starting_Page': 175, 'Office_X1': 104, 'Ending_Page': 177, 'Office_X2': 511, 'Page_Range': [175, 176, 177]}
# Starting at175|Count is1
# Continuing at176|Count is2
# Ending at177|Count is3
# {'Starting_Page': 177, 'Office_X1': 511, 'Ending_Page': 181, 'Office_X2': 233, 'Page_Range': [177, 178, 179, 180, 181]}
# Starting at177|Count is1
# Continuing at178|Count is2
# Continuing at179|Count is3
# Continuing at180|Count is4
# Ending at181|Count is5
# {'Starting_Page': 181, 'Office_X1': 233, 'Ending_Page': 182, 'Office_X2': 198, 'Page_Range': [181, 182]}
# Starting at181|Count is1
# Ending at182|Count is2
# {'Starting_Page': 182, 'Office_X1': 198, 'Ending_Page': 185, 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 185, 'Office_X1': None, 'Ending_Page': 187, 'Office_X2': 313, 'Page_Range': [185, 186, 187]}
# Starting at185|Count is1
# Continuing at186|Count is2
# Ending at187|Count is3
# {'Starting_Page': 187, 'Office_X1': 313, 'Ending_Page': 188, 'Office_X2': 389, 'Page_Range': [187, 188]}
# Starting at187|Count is1
# Ending at188|Count is2
# {'Starting_Page': 188, 'Office_X1': 389, 'Ending_Page': 190, 'Office_X2': 398, 'Page_Range': [188, 189, 190]}
# Starting at188|Count is1
# Continuing at189|Count is2
# Ending at190|Count is3
# {'Starting_Page': 190, 'Office_X1': 398, 'Ending_Page': 191, 'Office_X2': 328, 'Page_Range': [190, 191]}
# Starting at190|Count is1
# Ending at191|Count is2
# {'Starting_Page': 191, 'Office_X1': 328, 'Ending_Page': 192, 'Office_X2': 143, 'Page_Range': [191, 192]}
# Starting at191|Count is1
# Ending at192|Count is2
# {'Starting_Page': 192, 'Office_X1': 143, 'Ending_Page': 196, 'Office_X2': 171, 'Page_Range': [192, 193, 194, 195, 196]}
# Starting at192|Count is1
# Continuing at193|Count is2
# Continuing at194|Count is3
# Continuing at195|Count is4
# Ending at196|Count is5
# {'Starting_Page': 196, 'Office_X1': 161, 'Ending_Page': 197, 'Office_X2': 438, 'Page_Range': [196, 197]}
# Starting at196|Count is1
# Ending at197|Count is2
# {'Starting_Page': 197, 'Office_X1': 438, 'Ending_Page': 199, 'Office_X2': 253, 'Page_Range': [197, 198, 199]}
# Starting at197|Count is1
# Continuing at198|Count is2
# Ending at199|Count is3
# {'Starting_Page': 199, 'Office_X1': 253, 'Ending_Page': 203, 'Office_X2': 258, 'Page_Range': [199, 200, 201, 202, 203]}
# Starting at199|Count is1
# Continuing at200|Count is2
# Continuing at201|Count is3
# Continuing at202|Count is4
# Ending at203|Count is5
# {'Starting_Page': 207, 'Office_X1': 556, 'Ending_Page': 210, 'Office_X2': 458, 'Page_Range': [207, 208, 209, 210]}
# Starting at207|Count is1
# Continuing at208|Count is2
# Continuing at209|Count is3
# Ending at210|Count is4
# {'Starting_Page': 210, 'Office_X1': 448, 'Ending_Page': 217, 'Office_X2': 449, 'Page_Range': [210, 211, 212, 213, 214, 215, 216, 217]}
# Starting at210|Count is1
# Continuing at211|Count is2
# Continuing at212|Count is3
# Continuing at213|Count is4
# Continuing at214|Count is5
# Continuing at215|Count is6
# Continuing at216|Count is7
# Ending at217|Count is8
# {'Starting_Page': 217, 'Office_X1': 449, 'Ending_Page': 219, 'Office_X2': 488, 'Page_Range': [217, 218, 219]}
# Starting at217|Count is1
# Continuing at218|Count is2
# Ending at219|Count is3
# {'Starting_Page': 219, 'Office_X1': 478, 'Ending_Page': 221, 'Office_X2': 418, 'Page_Range': [219, 220, 221]}
# Starting at219|Count is1
# Continuing at220|Count is2
# Ending at221|Count is3
# {'Starting_Page': 221, 'Office_X1': 408, 'Ending_Page': 222, 'Office_X2': 186, 'Page_Range': [221, 222]}
# Starting at221|Count is1
# Ending at222|Count is2
# {'Starting_Page': 222, 'Office_X1': 176, 'Ending_Page': 224, 'Office_X2': 479, 'Page_Range': [222, 223, 224]}
# Starting at222|Count is1
# Continuing at223|Count is2
# Ending at224|Count is3
# {'Starting_Page': 224, 'Office_X1': 479, 'Ending_Page': 227, 'Office_X2': 424, 'Page_Range': [224, 225, 226, 227]}
# Starting at224|Count is1
# Continuing at225|Count is2
# Continuing at226|Count is3
# Ending at227|Count is4
# {'Starting_Page': 227, 'Office_X1': 424, 'Ending_Page': 228, 'Office_X2': 381, 'Page_Range': [227, 228]}
# Starting at227|Count is1
# Ending at228|Count is2
# {'Starting_Page': 228, 'Office_X1': 381, 'Ending_Page': 252, 'Office_X2': 284, 'Page_Range': [228, 229, 230, 231, 232, 233, 234, 235, 236, 237, 238, 239, 240, 241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252]}
# Starting at228|Count is1
# Continuing at229|Count is2
# Continuing at230|Count is3
# Continuing at231|Count is4
# Continuing at232|Count is5
# Continuing at233|Count is6
# Continuing at234|Count is7
# Continuing at235|Count is8
# Continuing at236|Count is9
# Continuing at237|Count is10
# Continuing at238|Count is11
# Continuing at239|Count is12
# Continuing at240|Count is13
# Continuing at241|Count is14
# Continuing at242|Count is15
# Continuing at243|Count is16
# Continuing at244|Count is17
# Continuing at245|Count is18
# Continuing at246|Count is19
# Continuing at247|Count is20
# Continuing at248|Count is21
# Continuing at249|Count is22
# Continuing at250|Count is23
# Continuing at251|Count is24
# Ending at252|Count is25
# {'Starting_Page': 252, 'Office_X1': 284, 'Ending_Page': 257, 'Office_X2': 247, 'Page_Range': [252, 253, 254, 255, 256, 257]}
# Starting at252|Count is1
# Continuing at253|Count is2
# Continuing at254|Count is3
# Continuing at255|Count is4
# Continuing at256|Count is5
# Ending at257|Count is6
# {'Starting_Page': 257, 'Office_X1': 247, 'Ending_Page': 263, 'Office_X2': 359, 'Page_Range': [257, 258, 259, 260, 261, 262, 263]}
# Starting at257|Count is1
# Continuing at258|Count is2
# Continuing at259|Count is3
# Continuing at260|Count is4
# Continuing at261|Count is5
# Continuing at262|Count is6
# Ending at263|Count is7
# {'Starting_Page': 263, 'Office_X1': 349, 'Ending_Page': 271, 'Office_X2': 417, 'Page_Range': [263, 264, 265, 266, 267, 268, 269, 270, 271]}
# Starting at263|Count is1
# Continuing at264|Count is2
# Continuing at265|Count is3
# Continuing at266|Count is4
# Continuing at267|Count is5
# Continuing at268|Count is6
# Continuing at269|Count is7
# Continuing at270|Count is8
# Ending at271|Count is9
# {'Starting_Page': 271, 'Office_X1': 417, 'Ending_Page': 272, 'Office_X2': 39, 'Page_Range': [271, 272]}
# Starting at271|Count is1
# Ending at272|Count is2
# {'Starting_Page': 272, 'Office_X1': 39, 'Ending_Page': 275, 'Office_X2': 214, 'Page_Range': [272, 273, 274, 275]}
# Starting at272|Count is1
# Continuing at273|Count is2
# Continuing at274|Count is3
# Ending at275|Count is4
# {'Starting_Page': 275, 'Office_X1': 214, 'Ending_Page': 277, 'Office_X2': 276, 'Page_Range': [275, 276, 277]}
# Starting at275|Count is1
# Continuing at276|Count is2
# Ending at277|Count is3
# {'Starting_Page': 277, 'Office_X1': 276, 'Ending_Page': 279, 'Office_X2': 323, 'Page_Range': [277, 278, 279]}
# Starting at277|Count is1
# Continuing at278|Count is2
# Ending at279|Count is3
# {'Starting_Page': 279, 'Office_X1': 323, 'Ending_Page': 281, 'Office_X2': 224, 'Page_Range': [279, 280, 281]}
# Starting at279|Count is1
# Continuing at280|Count is2
# Ending at281|Count is3
# {'Starting_Page': 281, 'Office_X1': 224, 'Ending_Page': 284, 'Office_X2': 384, 'Page_Range': [281, 282, 283, 284]}
# Starting at281|Count is1
# Continuing at282|Count is2
# Continuing at283|Count is3
# Ending at284|Count is4
# {'Starting_Page': 284, 'Office_X1': 384, 'Ending_Page': 286, 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 286, 'Office_X1': None, 'Ending_Page': 288, 'Office_X2': 156, 'Page_Range': [286, 287, 288]}
# Starting at286|Count is1
# Continuing at287|Count is2
# Ending at288|Count is3
# {'Starting_Page': 288, 'Office_X1': 146, 'Ending_Page': 290, 'Office_X2': 418, 'Page_Range': [288, 289, 290]}
# Starting at288|Count is1
# Continuing at289|Count is2
# Ending at290|Count is3
# {'Starting_Page': 290, 'Office_X1': 408, 'Ending_Page': 292, 'Office_X2': 80, 'Page_Range': [290, 291, 292]}
# Starting at290|Count is1
# Continuing at291|Count is2
# Ending at292|Count is3
# {'Starting_Page': 292, 'Office_X1': 80, 'Ending_Page': 296, 'Office_X2': 455, 'Page_Range': [292, 293, 294, 295, 296]}
# Starting at292|Count is1
# Continuing at293|Count is2
# Continuing at294|Count is3
# Continuing at295|Count is4
# Ending at296|Count is5
# {'Starting_Page': 296, 'Office_X1': 445, 'Ending_Page': 321, 'Office_X2': 208, 'Page_Range': [296, 297, 298, 299, 300, 301, 302, 303, 304, 305, 306, 307, 308, 309, 310, 311, 312, 313, 314, 315, 316, 317, 318, 319, 320, 321]}
# Starting at296|Count is1
# Continuing at297|Count is2
# Continuing at298|Count is3
# Continuing at299|Count is4
# Continuing at300|Count is5
# Continuing at301|Count is6
# Continuing at302|Count is7
# Continuing at303|Count is8
# Continuing at304|Count is9
# Continuing at305|Count is10
# Continuing at306|Count is11
# Continuing at307|Count is12
# Continuing at308|Count is13
# Continuing at309|Count is14
# Continuing at310|Count is15
# Continuing at311|Count is16
# Continuing at312|Count is17
# Continuing at313|Count is18
# Continuing at314|Count is19
# Continuing at315|Count is20
# Continuing at316|Count is21
# Continuing at317|Count is22
# Continuing at318|Count is23
# Continuing at319|Count is24
# Continuing at320|Count is25
# Ending at321|Count is26
# {'Starting_Page': 321, 'Office_X1': 208, 'Ending_Page': 325, 'Office_X2': 328, 'Page_Range': [321, 322, 323, 324, 325]}
# Starting at321|Count is1
# Continuing at322|Count is2
# Continuing at323|Count is3
# Continuing at324|Count is4
# Ending at325|Count is5
# {'Starting_Page': 325, 'Office_X1': None, 'Ending_Page': 327, 'Office_X2': 377, 'Page_Range': [325, 326, 327]}
# Starting at325|Count is1
# Continuing at326|Count is2
# Ending at327|Count is3
# {'Starting_Page': 327, 'Office_X1': 377, 'Ending_Page': 336, 'Office_X2': 80, 'Page_Range': [327, 328, 329, 330, 331, 332, 333, 334, 335, 336]}
# Starting at327|Count is1
# Continuing at328|Count is2
# Continuing at329|Count is3
# Continuing at330|Count is4
# Continuing at331|Count is5
# Continuing at332|Count is6
# Continuing at333|Count is7
# Continuing at334|Count is8
# Continuing at335|Count is9
# Ending at336|Count is10
# {'Starting_Page': 336, 'Office_X1': 80, 'Ending_Page': 337, 'Office_X2': 'NA', 'Page_Range': 'NA'}
# {'Starting_Page': 337, 'Office_X1': None, 'Ending_Page': 339, 'Office_X2': 20, 'Page_Range': 'NA'}
# {'Starting_Page': 339, 'Office_X1': None, 'Ending_Page': 342, 'Office_X2': 146, 'Page_Range': [339, 340, 341, 342]}
# Starting at339|Count is1
# Continuing at340|Count is2
# Continuing at341|Count is3
# Ending at342|Count is4
# {'Starting_Page': 342, 'Office_X1': None, 'Ending_Page': 343, 'Office_X2': 405, 'Page_Range': [342, 343]}
# Starting at342|Count is1
# Ending at343|Count is2
# {'Starting_Page': 344, 'Office_X1': 422, 'Ending_Page': 2, 'Office_X2': 28, 'Page_Range': []}
