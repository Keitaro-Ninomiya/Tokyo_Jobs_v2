# %%
import json
import os
import pandas as pd
import numpy as np
import cv2

Year='1941'
Showa='16'

# %%
file_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Processed_Data\\'+Year+'\\DataFrame_Office.json'
with open(file_path, encoding="utf-8") as f:
    dta = json.loads(f.read())
df = pd.read_csv(r'C:/Users/Keitaro Ninomiya/Box/Research Notes (keitaro2@illinois.edu)/Tokyo_Jobs/Processed_Data/Index/S'+Showa+'.csv')
df=df.drop(df.columns[0], axis=1)

# %%
for n in range(77,len(df)):
    Row  = df.iloc[n]
    Dept=Row['Dept']
    Office=Row['Office']
    print(Dept,Office)
    try:
        Info=dta[str(Year)][Dept][Office]
    except:
        continue
    PageList=Info['Page_Range']
    print(Info)
    StrPage=PageList[0]
    StrPart=Info['StrPart']
    StrCord=Info['StrLocation']

    EndPage=PageList[-1]
    EndPart=Info['EndPart']
    EndCord=Info['EndLocation']

    if (StrPage=="N"):
        continue
    if (EndPage=="A"):
        continue
    if (StrCord=="NA"):
        continue
    if (EndCord=="NA"):
        continue

    path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\'+str(Year)+'\\'
    save_path='C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Office_Level\\'+str(Year)+'\\'+Dept+'\\'+Office+'\\'
    try:
        os.chdir(save_path)
    except:
        continue

    Count=1
    if (StrPage!=EndPage):
        print('Multiple Pages: Page'+str(StrPage)+' to '+str(EndPage))
        for Page in PageList:
            print(Page)
            if (Page==StrPage):
                if (StrPart=='Top'):                    
                    print("Starting at"+str(StrPage)+str(StrPart)+"|Count is"+str(Count))
                    img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\Top.jpg")
                    img=img[0:HH,0:StrCord]
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                    Count=Count+1

                    img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\"+'Btm'+".jpg")
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                    Count=Count+1
                    
                if (StrPart=='Btm'):
                    img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\Btm.jpg")
                    HH, WW = img.shape[:2]
                    img=img[0:HH,0:StrCord]
                    cv2.imwrite('Image'+str(Count)+'.png', img)
                    Count=Count+1
                

            if (Page!=StrPage)&(Page!=EndPage):
                img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\Top.jpg")
                cv2.imwrite('Image'+str(Count)+'.png', img)
                Count=Count+1

                img=cv2.imread(path+"Page"+"{:03d}".format(Page)+"\\Btm.jpg")
                cv2.imwrite('Image'+str(Count)+'.png', img)
            
            if (Page==EndPage)&(EndPart=='Top'):
                print("Ending at"+str(EndPage)+"|Count is"+str(Count))
                img=cv2.imread(path+"Page"+"{:03d}".format(EndPage)+"\\Top.jpg")
                HH, WW = img.shape[:2]
                img=img[0:HH,EndCord:WW]
                cv2.imwrite('Image'+str(Count)+'.png', img)

            if (Page==EndPage)&(EndPart=='Btm'):
                print("Ending at"+str(EndPage)+"|Count is"+str(Count))
                img=cv2.imread(path+"Page"+"{:03d}".format(EndPage)+"\\Top.jpg")
                HH, WW = img.shape[:2]
                img=img[0:HH,0:WW]
                cv2.imwrite('Image'+str(Count)+'.png', img)
                Count=Count+1

                img=cv2.imread(path+"Page"+"{:03d}".format(EndPage)+"\\Btm.jpg")
                HH, WW = img.shape[:2]
                img=img[0:HH,EndCord:WW]
                cv2.imwrite('Image'+str(Count)+'.png', img)

            else:
                print('Halt!!')
                continue
                

    if (StrPage==EndPage)&(StrPart!=EndPart):
        img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\Top.jpg")
        HH, WW = img.shape[:2]
        img=img[0:HH,0:StrCord]
        cv2.imwrite('Image'+str(Count)+'.png', img)
        Count=Count+1

        img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\Btm.jpg")
        HH, WW = img.shape[:2]
        img=img[0:HH,EndCord:WW]
        cv2.imwrite('Image'+str(Count)+'.png', img)

    if (StrPage==EndPage)&(StrPart==EndPart):
        img=cv2.imread(path+"Page"+"{:03d}".format(StrPage)+"\\"+StrPart+".jpg")
        HH, WW = img.shape[:2]
        img=img[0:HH,EndCord:StrCord]
        cv2.imwrite('Image'+str(Count)+'.png', img)
# Out:
# 土木局 土木出張所
# {'StrPage': 94, 'StrLocation': 190, 'StrPart': 'Top', 'EndPage': 101, 'EndPart': 'Top', 'EndLocation': 402, 'Page_Range': [94, 95, 96, 97, 98, 99, 100, 101]}
# Multiple Pages: Page94 to 101
# 94
# Starting at94Top|Count is1
# Halt!!
# 95
# Halt!!
# 96
# Halt!!
# 97
# Halt!!
# 98
# Halt!!
# 99
# Halt!!
# 100
# Halt!!
# 101
# Ending at101|Count is9
# Halt!!
# 港湾局 庶務課
# {'StrPage': 101, 'StrLocation': 402, 'StrPart': 'Top', 'EndPage': 101, 'EndLocation': 395, 'Page_Range': [101], 'EndPart': 'Btm'}
# 港湾局 経理課
# {'StrPage': 101, 'StrLocation': 395, 'StrPart': 'Btm', 'EndPage': 102, 'EndLocation': 330, 'Page_Range': [101, 102], 'EndPart': 'Btm'}
# Multiple Pages: Page101 to 102
# 101
# Halt!!
# 102
# Ending at102|Count is2
# 港湾局 計書課
# {'StrPage': 102, 'StrLocation': 330, 'EndPage': 102, 'EndLocation': 391, 'Page_Range': [102], 'EndPart': 'Btm', 'StrPart': 'Top'}
# 港湾局 工事課
# {'StrPage': 102, 'StrLocation': 391, 'StrPart': 'Btm', 'EndPage': 103, 'EndLocation': 403, 'Page_Range': [102, 103], 'EndPart': 'Btm'}
# Multiple Pages: Page102 to 103
# 102
# Halt!!
# 103
# Ending at103|Count is2
# 港湾局 港務所
# {'StrPage': 103, 'StrLocation': 403, 'StrPart': 'Btm', 'EndPage': 104, 'EndPart': 'Top', 'EndLocation': 290, 'Page_Range': [103, 104]}
# Multiple Pages: Page103 to 104
# 103
# Halt!!
# 104
# Ending at104|Count is2
# Halt!!
# 港湾局 副収入役室
# {'StrPage': 104, 'StrLocation': 290, 'StrPart': 'Top', 'EndPage': 104, 'EndLocation': 180, 'Page_Range': [104], 'EndPart': 'Top'}
# 港湾局 臨時飛行場建設事務所
# {'StrPage': 104, 'StrLocation': 180, 'EndPage': 105, 'EndPart': 'Top', 'EndLocation': 490, 'Page_Range': [104, 105], 'StrPart': 'Top'}
# Multiple Pages: Page104 to 105
# 104
# Starting at104Top|Count is1
# Halt!!
# 105
# Ending at105|Count is3
# Halt!!
# 水道局 庶務課
# {'StrPage': 124, 'StrLocation': 490, 'StrPart': 'Top', 'EndPage': 124, 'EndLocation': 428, 'Page_Range': [124], 'EndPart': 'Btm'}
# 水道局 会計課
# {'StrPage': 105, 'StrLocation': 171, 'StrPart': 'Btm', 'EndPage': 106, 'EndPart': 'Top', 'EndLocation': 190, 'Page_Range': [105, 106]}
# Multiple Pages: Page105 to 106
# 105
# Halt!!
# 106
# Ending at106|Count is2
# Halt!!
# 水道局 営業課
# {'StrPage': 106, 'StrLocation': 190, 'StrPart': 'Top', 'EndPage': 116, 'EndPart': 'Btm', 'EndLocation': 240, 'Page_Range': [106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116]}
# Multiple Pages: Page106 to 116
# 106
# Starting at106Top|Count is1
# Halt!!
# 107
# Halt!!
# 108
# Halt!!
# 109
# Halt!!
# 110
# Halt!!
# 111
# Halt!!
# 112
# Halt!!
# 113
# Halt!!
# 114
# Halt!!
# 115
# Halt!!
# 116
# Ending at116|Count is12
# 水道局 給水課
# {'StrPage': 116, 'StrLocation': 240, 'StrPart': 'Btm', 'EndPage': 118, 'EndLocation': 70, 'Page_Range': [116, 117, 118], 'EndPart': 'Top'}
# Multiple Pages: Page116 to 118
# 116
# Halt!!
# 117
# Halt!!
# 118
# Ending at118|Count is3
# Halt!!
# 水道局 計書課
# {'StrPage': 118, 'StrLocation': 70, 'EndPage': 119, 'EndPart': 'Top', 'EndLocation': 403, 'Page_Range': [118, 119], 'StrPart': 'Top'}
# Multiple Pages: Page118 to 119
# 118
# Starting at118Top|Count is1
# Halt!!
# 119
# Ending at119|Count is3
# Halt!!
# 水道局 拡張課
# {'StrPage': 119, 'StrLocation': 403, 'StrPart': 'Top', 'EndPage': 123, 'EndLocation': 180, 'Page_Range': [119, 120, 121, 122, 123], 'EndPart': 'Btm'}
# Multiple Pages: Page119 to 123
# 119
# Starting at119Top|Count is1
# Halt!!
# 120
# Halt!!
# 121
# Halt!!
# 122
# Halt!!
# 123
# Ending at123|Count is6
# 水道局 小河内貯水池建設事務所
# {'StrPage': 123, 'StrLocation': 180, 'StrPart': 'Btm', 'EndPage': 121, 'EndPart': 'Top', 'EndLocation': 505, 'Page_Range': []}
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Temp\ipykernel_28600\2160045439.py in <module>
#      10     PageList=Info['Page_Range']
#      11     print(Info)
# ---> 12     StrPage=PageList[0]
#      13     StrPart=Info['StrPart']
#      14     StrCord=Info['StrLocation']
#
# IndexError: list index out of range

# %%
dta[Year]['総務局']
# Out:
# {'文書課': {'StrPage': 4,
#   'StrLocation': 356,
#   'StrPart': 'Top',
#   'EndPage': 5,
#   'EndPart': 'Top',
#   'EndLocation': 375,
#   'Page_Range': [4, 5]},
#  '人事課': {'StrPage': 5,
#   'StrLocation': 375,
#   'StrPart': 'Top',
#   'EndPage': 5,
#   'EndPart': 'Btm',
#   'EndLocation': 345,
#   'Page_Range': [5]},
#  '吏務課': {'StrPage': 5,
#   'StrLocation': 345,
#   'StrPart': 'Btm',
#   'EndPage': 6,
#   'EndPart': 'Top',
#   'EndLocation': 154,
#   'Page_Range': [5, 6]},
#  '議案課': {'StrPage': 6,
#   'StrLocation': 154,
#   'StrPart': 'Top',
#   'EndPage': 6,
#   'EndLocation': 288,
#   'Page_Range': [6],
#   'EndPart': 'Btm'},
#  '企画課': {'StrPage': 6,
#   'StrLocation': 288,
#   'EndPage': 7,
#   'EndLocation': 319,
#   'Page_Range': [6, 7],
#   'StrPart': 'Btm',
#   'EndPart': 'Top'},
#  '都市計画課': {'StrPage': 7,
#   'StrLocation': 319,
#   'EndPage': 8,
#   'EndLocation': 371,
#   'Page_Range': [7, 8],
#   'EndPart': 'Btm',
#   'StrPart': 'Top'},
#  '統計課': {'StrPage': 8,
#   'StrLocation': 371,
#   'StrPart': 'Btm',
#   'EndPage': 10,
#   'EndPart': 'Top',
#   'EndLocation': 241,
#   'Page_Range': [8, 9, 10]},
#  '情報課': {'StrPage': 10,
#   'StrLocation': 241,
#   'StrPart': 'Top',
#   'EndPage': 10,
#   'EndPart': 'Btm',
#   'EndLocation': 120,
#   'Page_Range': [10]}}
