# %% [markdown]
# - These codes splits the digital archived copies into page units.
#
# - The codes are executed in the following order.
#     1. Remove redundant spaces around a digital copies.
#
#         <=Removes the areas of the image covered with while color.
#
#     2. Cuts the page at the border of the two pages.
#
#         Borders are detected by searching for a black ertical line.

# %% [markdown]
# Code 1: Define the functions and install packages

# %%
import matplotlib.pyplot as plt
from scipy.signal import find_peaks
import numpy as np
import cv2
import os


def Split(Page):    
    img = cv2.imread(path+"Page"+Page+".jpg")
    hh, ww = img.shape[:2]
    # convert to grayscale
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    # threshold gray image
    thresh = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)[1]

    # count number of non-zero pixels in each row. 
    countCol = np.count_nonzero(thresh, axis=0)
    countRow = np.count_nonzero(thresh, axis=1)

    ### Find location of biggest jumps/falls.
    ###Top and Bottom
    peaks, _ = find_peaks(countRow, distance=15)
    HeightTop=abs(np.diff(countRow[peaks][peaks<hh//5]))
    HeightBtm=abs(np.diff(countRow[peaks][peaks>4*hh//5]))
    max1Height=np.sort(HeightTop)[-1]
    max2Height=np.sort(HeightBtm)[-1]
    X=peaks[ : -1][abs(np.diff(countRow[peaks]))==max1Height][0]
    Y=peaks[ : -1][abs(np.diff(countRow[peaks]))==max2Height][0]
    Top=min([X,Y])
    Btm=max([X,Y])

    ###Left and Right
    peaks, _ = find_peaks(countCol, distance=50)
    HeightLeft=abs(np.diff(countCol[peaks][peaks<ww//5]))
    HeightRight=abs(np.diff(countCol[peaks][peaks>4*ww//5]))
    max1Height=np.sort(HeightLeft)[-1]
    max2Height=np.sort(HeightRight)[-1]
    V=peaks[ : -1][abs(np.diff(countCol[peaks]))==max1Height][0]
    Z=peaks[ : -1][abs(np.diff(countCol[peaks]))==max2Height][0]
    Left=min([V,Z])
    Right=max([V,Z])

    cropped=img[Top:Btm, Left:Right] 
    #cv2.imshow("Result", cropped)
    #cv2.waitKey(0)
    
    #Code for cutting image Side-by-Side
    # read image+crop image
    crop_img=img[Top:Btm-30, Left:Right]
    HH, WW = crop_img.shape[:2]
    # convert to grayscale
    gray = cv2.cvtColor(crop_img,cv2.COLOR_BGR2GRAY)
    # threshold gray image
    thresh = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)[1]

    # count number of non-zero pixels in each column and row. 
    countCol = np.count_nonzero(thresh, axis=0)
    countRow = np.count_nonzero(thresh, axis=1)

    ### This finds the height of the lowest valley
    peaks, _ = find_peaks(-countCol, distance=30)
    maxHeight=np.sort(abs(np.diff(countCol[peaks][(peaks<4*WW//7) & (peaks>3*WW//7)])))[-1]
    Border=peaks[ : -1][abs(np.diff(countCol[peaks]))==maxHeight][0]

    ### loop over contours and get bounding boxes and ycenter and draw horizontal line at ycenter
    result = crop_img.copy()
    LeftImage=result[0:HH,0:Border]
    RighImage=result[0:HH,Border:WW]
    #cv2.imshow("LeftImage", LeftImage)
    #cv2.imshow("RightImage", RighImage)
    #cv2.waitKey(0)

    return(list((LeftImage,RighImage)))

# %% [markdown]
# Code 2: Define Years

# %%
Year=1935

# %% [markdown]
# Code 3: We need to create a seperate directory for each page of the archived copy.
# Check the starting and ending page of the staff directory and define a variable with the numbers.

# %%
StrPage=51
EndPage=126

#Set directory path
save_path="C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\"+str(Year)+"\\"

#Create directory for each page
for Num in range(StrPage,EndPage+1):
    Page="Page"+"{:03d}".format(2*(Num-StrPage))
    path2 = os.path.join(save_path, Page)
    os.mkdir(path2)

    Page="Page"+"{:03d}".format(2*(Num-StrPage)+1)
    path2 = os.path.join(save_path, Page)
    os.mkdir(path2)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# C:\Temp\ipykernel_22308\2101125676.py in <module>
#       9     Page="Page"+"{:03d}".format(2*(Num-StrPage))
#      10     path2 = os.path.join(save_path, Page)
# ---> 11     os.mkdir(path2)
#      12
#      13     Page="Page"+"{:03d}".format(2*(Num-StrPage)+1)
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs\\Raw_Data\\Splited\\1935\\Page000'

# %% [markdown]
# Code 4: Splitting copies into pages.
# Each page is saved into the corresponding directory that we made on Code 2.

# %%
# read image+crop image
import os
path=r'C:\\Users\\Keitaro Ninomiya\\Box\\Research Notes (keitaro2@illinois.edu)\\Tokyo_Jobs/Raw_Data\\Metropolitan_DA\\'+str(Year)+'\\Line\\'
for Num in range(StrPage,EndPage):
    print(Num)
    Righ=Split("{:03d}".format(Num))[1]
    Left=Split("{:03d}".format(Num))[0]

    Page="Page"+"{:03d}".format(2*(Num-StrPage))
    path2 = os.path.join(save_path, Page)
    print(path2+"\\"+Page+".jpg")
    cv2.imshow('Right',Righ)
    cv2.waitKey(0)
    cv2.imwrite(path2+"\\"+Page+".jpg", Righ)

    Page="Page"+"{:03d}".format(2*(Num-StrPage)+1)
    path2 = os.path.join(save_path, Page)
    print(path2+"\\"+Page+".jpg")
    cv2.imshow('Left',Left)
    cv2.waitKey(0)
    cv2.imwrite(path2+"\\"+Page+".jpg", Left)
# Out:
# 51
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page000\Page000.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page001\Page001.jpg
# 52
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page002\Page002.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page003\Page003.jpg
# 53
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page004\Page004.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page005\Page005.jpg
# 54
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page006\Page006.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page007\Page007.jpg
# 55
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page008\Page008.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page009\Page009.jpg
# 56
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page010\Page010.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page011\Page011.jpg
# 57
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page012\Page012.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page013\Page013.jpg
# 58
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page014\Page014.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page015\Page015.jpg
# 59
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page016\Page016.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page017\Page017.jpg
# 60
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page018\Page018.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page019\Page019.jpg
# 61
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page020\Page020.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page021\Page021.jpg
# 62
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page022\Page022.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page023\Page023.jpg
# 63
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page024\Page024.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page025\Page025.jpg
# 64
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page026\Page026.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page027\Page027.jpg
# 65
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page028\Page028.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page029\Page029.jpg
# 66
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page030\Page030.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page031\Page031.jpg
# 67
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page032\Page032.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page033\Page033.jpg
# 68
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page034\Page034.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page035\Page035.jpg
# 69
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page036\Page036.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page037\Page037.jpg
# 70
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page038\Page038.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page039\Page039.jpg
# 71
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page040\Page040.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page041\Page041.jpg
# 72
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page042\Page042.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page043\Page043.jpg
# 73
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page044\Page044.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page045\Page045.jpg
# 74
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page046\Page046.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page047\Page047.jpg
# 75
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page048\Page048.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page049\Page049.jpg
# 76
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page050\Page050.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page051\Page051.jpg
# 77
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page052\Page052.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page053\Page053.jpg
# 78
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page054\Page054.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page055\Page055.jpg
# 79
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page056\Page056.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page057\Page057.jpg
# 80
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page058\Page058.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page059\Page059.jpg
# 81
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page060\Page060.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page061\Page061.jpg
# 82
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page062\Page062.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page063\Page063.jpg
# 83
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page064\Page064.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\
jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page193\Page193.jpg
# 148
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page194\Page194.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page195\Page195.jpg
# 149
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page196\Page196.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page197\Page197.jpg
# 150
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page198\Page198.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page199\Page199.jpg
# 151
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page200\Page200.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page201\Page201.jpg
# 152
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page202\Page202.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page203\Page203.jpg
# 153
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page204\Page204.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page205\Page205.jpg
# 154
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page206\Page206.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page207\Page207.jpg
# 155
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page208\Page208.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page209\Page209.jpg
# 156
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page210\Page210.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page211\Page211.jpg
# 157
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page212\Page212.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page213\Page213.jpg
# 158
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page214\Page214.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page215\Page215.jpg
# 159
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page216\Page216.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page217\Page217.jpg
# 160
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page218\Page218.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page219\Page219.jpg
# 161
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page220\Page220.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page221\Page221.jpg
# 162
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page222\Page222.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page223\Page223.jpg
# 163
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page224\Page224.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page225\Page225.jpg
# 164
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page226\Page226.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page227\Page227.jpg
# 165
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page228\Page228.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page229\Page229.jpg
# 166
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page230\Page230.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page231\Page231.jpg
# 167
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page232\Page232.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page233\Page233.jpg
# 168
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page234\Page234.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page235\Page235.jpg
# 169
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page236\Page236.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page237\Page237.jpg
# 170
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page238\Page238.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page239\Page239.jpg
# 171
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page240\Page240.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page241\Page241.jpg
# 172
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page242\Page242.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page243\Page243.jpg
# 173
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page244\Page244.jpg
# C:\Users\Keitaro Ninomiya\Box\Research Notes (keitaro2@illinois.edu)\Tokyo_Jobs\Raw_Data\Splited\1935\Page245\Page245.jpg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Temp\ipykernel_22308\1035122657.py in <module>
#      18     print(path2+"\\"+Page+".jpg")
#      19     cv2.imshow('Left',Left)
# ---> 20     cv2.waitKey(0)
#      21     cv2.imwrite(path2+"\\"+Page+".jpg", Left)
#
# KeyboardInterrupt:

# %%
Page='203'
img = cv2.imread(path+"Page"+Page+".jpg")
hh, ww = img.shape[:2]
# convert to grayscale
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
# threshold gray image
thresh = cv2.threshold(gray, 200, 255, cv2.THRESH_BINARY)[1]

# count number of non-zero pixels in each row. 
countCol = np.count_nonzero(thresh, axis=0)
countRow = np.count_nonzero(thresh, axis=1)

### Find location of biggest jumps/falls.
###Top and Bottom
peaks, _ = find_peaks(countRow, distance=15)
HeightTop=abs(np.diff(countRow[peaks][peaks<hh//5]))
HeightBtm=abs(np.diff(countRow[peaks][peaks>4*hh//5]))
max1Height=np.sort(HeightTop)[-1]
max2Height=np.sort(HeightBtm)[-1]
X=peaks[ : -1][abs(np.diff(countRow[peaks]))==max1Height][0]
Y=peaks[ : -1][abs(np.diff(countRow[peaks]))==max2Height][0]
Top=min([X,Y])
Btm=max([X,Y])

###Left and Right
peaks, _ = find_peaks(countCol, distance=50)
HeightLeft=abs(np.diff(countCol[peaks][peaks<ww//5]))
HeightRight=abs(np.diff(countCol[peaks][peaks>4*ww//5]))
max1Height=np.sort(HeightLeft)[-1]
max2Height=np.sort(HeightRight)[-1]
V=peaks[ : -1][abs(np.diff(countCol[peaks]))==max1Height][0]
Z=peaks[ : -1][abs(np.diff(countCol[peaks]))==max2Height][0]
Left=min([V,Z])
Right=max([V,Z])
print(V,Z)
cropped=img[Top:Btm, Left:Right] 
#cv2.imshow("Result", cropped)
#cv2.waitKey(0)
# Out:
# 69 1221
