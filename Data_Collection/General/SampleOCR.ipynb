# %%
api_url='https://1srlcnzf08.apigw.ntruss.com/custom/v1/2412/9a859f9b3a7d952aad17f388d1a445041f8aef0f1eccc6fcce8d3a856272fcbd/general'
secret_key='eEhyV0NGRlRLVXpZVWZnWFNDamRVaWFYZ1NSQ1NKSFI='

# %%
origin='C:/Users/Keitaro Ninomiya/Box/Research Notes (keitaro2@illinois.edu)/'

# %%
import json, os, cv2,pandas as pd
from OCR import Clova

Year,Showa='1942','17'

# %%
Page=35
res=Clova(origin,Page,api_url,secret_key)

# %%
[d for d in res['fields'] if d['inferText']=='雇']
# Out:
# [{'valueType': 'ALL',
#   'boundingPoly': {'vertices': [{'x': 2242.0, 'y': 476.0},
#     {'x': 2286.0, 'y': 476.0},
#     {'x': 2286.0, 'y': 522.0},
#     {'x': 2242.0, 'y': 522.0}]},
#   'inferText': '雇',
#   'inferConfidence': 1.0,
#   'type': 'NORMAL',
#   'lineBreak': True},
#  {'valueType': 'ALL',
#   'boundingPoly': {'vertices': [{'x': 987.0, 'y': 496.0},
#     {'x': 1029.0, 'y': 496.0},
#     {'x': 1029.0, 'y': 540.0},
#     {'x': 987.0, 'y': 540.0}]},
#   'inferText': '雇',
#   'inferConfidence': 0.9994,
#   'type': 'NORMAL',
#   'lineBreak': False}]
