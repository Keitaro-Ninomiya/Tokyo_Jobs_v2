# %% [markdown]
# # 1. Cut page
# - Detect the starting location of position.
# - Save the y axis of the position.
# - Crop out upper space of page.
# - Define starting position of the lower part.
# - Repeat for the number of parts in the position.
# - Remove the lower part of page.

# %% [markdown]
# # 2. Read Page
# - Separate wage row and name row.
# - Apply Google Vision OCR to name row chunk.
# - Extract sequence of letter of the last row.

# %% [markdown]
# # 3. Collect data
# - Predict gender based on last letter of name.
# - Count number of staff.
